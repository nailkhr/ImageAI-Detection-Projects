# %%
# !pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.12.0-cp310-cp310-win_amd64.whl (1.9 kB)
# ...
#   Using cached tensorflow_intel-2.12.0-cp310-cp310-win_amd64.whl (272.8 MB)
# ...
#      ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#      - -------------------------------------- 0.4/14.6 MB 11.8 MB/s eta 0:00:02
#      -- ------------------------------------- 1.1/14.6 MB 13.5 MB/s eta 0:00:02
#      --- ------------------------------------ 1.3/14.6 MB 10.6 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.8/14.6 MB 10.1 MB/s eta 0:00:02
#      ----- ---------------------------------- 2.1/14.6 MB 9.4 MB/s eta 0:00:02
#      ------ --------------------------------- 2.3/14.6 MB 9.1 MB/s eta 0:00:02
#      ------ --------------------------------- 2.5/14.6 MB 8.1 MB/s eta 0:00:02
#      ------- -------------------------------- 2.8/14.6 MB 7.8 MB/s eta 0:00:02
#      -------- ------------------------------- 3.1/14.6 MB 8.0 MB/s eta 0:00:02
# ...

# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.7.0.72-cp37-abi3-win_amd64.whl (38.2 MB)
# ...

# %%
# !pip install keras

# %%
# !pip install imageAI --upgrade
# Out:
# ...
#   Using cached imageai-3.0.3-py3-none-any.whl (69 kB)
# ...

# %%
# !pip install --upgrade pip
# Out:
# ...
#   Using cached pip-23.1.2-py3-none-any.whl (2.1 MB)
# ERROR: To modify pip, please run the following command:
# D:\Program Files\anaconda3\envs\M7New\python.exe -m pip install --upgrade pip

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      --------------------------------------- 0.5/172.3 MB 14.5 MB/s eta 0:00:12
#      --------------------------------------- 1.1/172.3 MB 13.5 MB/s eta 0:00:13
#      --------------------------------------- 1.4/172.3 MB 12.6 MB/s eta 0:00:14
#      --------------------------------------- 1.8/172.3 MB 10.5 MB/s eta 0:00:17
#      ---------------------------------------- 2.0/172.3 MB 9.3 MB/s eta 0:00:19
#       --------------------------------------- 2.2/172.3 MB 8.4 MB/s eta 0:00:21
#       --------------------------------------- 2.6/172.3 MB 8.2 MB/s eta 0:00:21
#       --------------------------------------- 2.8/172.3 MB 8.2 MB/s eta 0:00:21
#       --------------------------------------- 3.1/172.3 MB 7.7 MB/s eta 0:00:22
#       --------------------------------------- 3.4/172.3 MB 7.8 MB/s eta 0:00:22
#       --------------------------------------- 3.6/172.3 MB 7.4 MB/s eta 0:00:23
# ...

# %%
from IPython.display import Image
Image('image-1.jpeg')

# %%
from IPython.display import Image
Image('image-2.jpg')

# %%
from imageai.Detection import ObjectDetection
import os

detector = ObjectDetection()
execution_path = os.getcwd()

# %%
model_path = "yolov3.pt"
input_path = "image-1.jpeg"
output_path = "newimages.jpeg"

detector = ObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath( os.path.join(execution_path , "yolov3.pt"))
detector.loadModel()
detections = detector.detectObjectsFromImage(input_image=os.path.join(execution_path , input_path), output_image_path=os.path.join(execution_path , output_path), minimum_percentage_probability=30)

# %%
for eachitem in detections:
    print(eachitem["name"] , " : ", eachitem["percentage_probability"])
# Out:
# person  :  99.94
# person  :  99.9
# person  :  87.1
# person  :  99.66
# person  :  99.86
# bicycle  :  99.95
# bus  :  99.86
# bus  :  94.95
# truck  :  91.04
# traffic light  :  99.92

# %%
from IPython.display import Image
Image('newimages.jpeg')
